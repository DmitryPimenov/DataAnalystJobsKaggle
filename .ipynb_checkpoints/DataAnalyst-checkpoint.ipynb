# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('DataAnalyst.csv')
data.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %%
data.shape
# Out:
# (2253, 16)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
data.describe(include='all')
data.describe(include=np.object_)
# Out:
#            Job Title             Salary Estimate  \
# count           2253                        2253
# unique          1272                          90
# top     Data Analyst  $41K-$78K (Glassdoor est.)
# freq             405                          57
#
#                                           Job Description  \
# count                                                2253
# unique                                               2253
# top     Job Description\nVoca Technology has immediate...
# freq                                                    1
#
#                                  Company Name      Location  Headquarters  \
# count                                    2252          2253          2253
# unique                                   1513           253           483
# top     Staffigo Technical Services, LLC\n5.0  New York, NY  New York, NY
# freq                                       58           310           206
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0       Rating      Founded
# count   2253.0000  2253.000000  2253.000000
# mean    1126.0000     3.160630  1398.522858
# std      650.5294     1.665228   901.929251
# min        0.0000    -1.000000    -1.000000
# 25%      563.0000     3.100000    -1.000000
# 50%     1126.0000     3.600000  1979.000000
# 75%     1689.0000     4.000000  2002.000000
# max     2252.0000     5.000000  2019.000000

# %%
data.mean()
# Out:
# Unnamed: 0    1126.000000
# Rating           3.160630
# Founded       1398.522858
# dtype: float64

# %%
data.median()
# Out:
# Unnamed: 0    1126.0
# Rating           3.6
# Founded       1979.0
# dtype: float64

# %%
data.max()
# Out:
# Unnamed: 0                                                        2252
# Job Title                          【1yr OPT+Intern】Data Analyst 保实习保就业
# Salary Estimate                                                     -1
# Job Description      现在就在微信 wuyuzhou0907\n现在就在微信 wuyuzhou0907\n现在就在...
# Rating                                                               5
# Location                                                  Yorktown, VA
# Headquarters                                       Zurich, Switzerland
# Size                                                           Unknown
# Founded                                                           2019
# Type of ownership                                              Unknown
# Industry                                                     Wholesale
# Sector                                                Travel & Tourism
# Revenue                                       Unknown / Non-Applicable
# ...

# %%
data.nunique()
# Out:
# Unnamed: 0           2253
# Job Title            1272
# Salary Estimate        90
# Job Description      2253
# Rating                 37
# Company Name         1513
# Location              253
# Headquarters          483
# Size                    9
# Founded               161
# Type of ownership      15
# Industry               89
# Sector                 25
# Revenue                14
# Competitors           291
# Easy Apply              2
# dtype: int64

# %%
#data.isna().sum()
data.isnull()
#data.isnull().sum()
# Out:
#       Unnamed: 0  Job Title  Salary Estimate  Job Description  Rating  \
# 0          False      False            False            False   False
# 1          False      False            False            False   False
# 2          False      False            False            False   False
# 3          False      False            False            False   False
# 4          False      False            False            False   False
# ...          ...        ...              ...              ...     ...
# 2248       False      False            False            False   False
# 2249       False      False            False            False   False
# 2250       False      False            False            False   False
# 2251       False      False            False            False   False
# 2252       False      False            False            False   False
#
#       Company Name  Location  Headquarters   Size  Founded  Type of ownership  \
# ...

# %%
data.dropna().head(10)
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
# 5           5                                       Data Analyst
# 6           6                       Business/Data Analyst (FP&A)
# 7           7                               Data Science Analyst
# 8           8                                       Data Analyst
# 9           9                      Data Analyst, Merchant Health
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
# 5  $37K-$66K (Glassdoor est.)
# ...

# %%
data.fillna(0).head(10)
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
# 5           5                                       Data Analyst
# 6           6                       Business/Data Analyst (FP&A)
# 7           7                               Data Science Analyst
# 8           8                                       Data Analyst
# 9           9                      Data Analyst, Merchant Health
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
# 5  $37K-$66K (Glassdoor est.)
# ...

# %%
data[['Salary Estimate','Rating', 'Location']].head(100)
# Out:
#                Salary Estimate  Rating      Location
# 0   $37K-$66K (Glassdoor est.)     3.2  New York, NY
# 1   $37K-$66K (Glassdoor est.)     3.8  New York, NY
# 2   $37K-$66K (Glassdoor est.)     3.4  New York, NY
# 3   $37K-$66K (Glassdoor est.)     4.1  New York, NY
# 4   $37K-$66K (Glassdoor est.)     3.9  New York, NY
# ..                         ...     ...           ...
# 95  $51K-$87K (Glassdoor est.)     3.2  New York, NY
# 96  $51K-$87K (Glassdoor est.)    -1.0  New York, NY
# 97  $51K-$87K (Glassdoor est.)     3.8  New York, NY
# 98  $51K-$87K (Glassdoor est.)     4.7  Brooklyn, NY
# 99  $51K-$87K (Glassdoor est.)     2.3  New York, NY
#
# [100 rows x 3 columns]

# %%
data.groupby('Salary Estimate').count()
# Out:
#                               Unnamed: 0  Job Title  Job Description  Rating  \
# Salary Estimate
# $110K-$190K (Glassdoor est.)          29         29               29      29
# $113K-$132K (Glassdoor est.)          29         29               29      29
# $24K-$48K (Glassdoor est.)            29         29               29      29
# $26K-$47K (Glassdoor est.)            29         29               29      29
# $27K-$52K (Glassdoor est.)            30         30               30      30
# ...                                  ...        ...              ...     ...
# $93K-$159K (Glassdoor est.)           25         25               25      25
# $97K-$129K (Glassdoor est.)           30         30               30      30
# $98K-$114K (Glassdoor est.)           30         30               30      30
# $99K-$178K (Glassdoor est.)           28         28               28      28
# -1                                     1          1                1       1
#
# ...

# %%
data.groupby('Rating').count()
# Out:
#         Unnamed: 0  Job Title  Salary Estimate  Job Description  Company Name  \
# Rating
# -1.0           272        272              272              272           271
#  1.0            10         10               10               10            10
#  1.6             2          2                2                2             2
#  1.7             2          2                2                2             2
#  1.8             2          2                2                2             2
#  1.9             2          2                2                2             2
#  2.0             6          6                6                6             6
#  2.1             4          4                4                4             4
#  2.2             3          3                3                3             3
#  2.3             9          9                9                9             9
#  2.4            10         10               10               10            10
# ...

# %%
data.groupby('Location').count()
# Out:
#                     Unnamed: 0  Job Title  Salary Estimate  Job Description  \
# Location
# Addison, TX                  1          1                1                1
# Alachua, FL                  1          1                1                1
# Alameda, CA                  1          1                1                1
# Alhambra, CA                 2          2                2                2
# Allegheny West, PA           2          2                2                2
# ...                        ...        ...              ...              ...
# Woodbridge, NJ               1          1                1                1
# Woodcliff Lake, NJ           1          1                1                1
# Woodland Hills, CA           6          6                6                6
# Woodridge, IL                2          2                2                2
# Yorktown, VA                 1          1                1                1
#
# ...

# %%
data.groupby(['Rating','Salary Estimate']).min()#.max().sum().mean() и т.д.
# Out:
#                                      Unnamed: 0  Founded
# Rating Salary Estimate
# -1.0   $110K-$190K (Glassdoor est.)        1479       -1
#        $113K-$132K (Glassdoor est.)         689       -1
#        $24K-$48K (Glassdoor est.)          1330       -1
#        $26K-$47K (Glassdoor est.)           421       -1
#        $27K-$52K (Glassdoor est.)           284       -1
# ...                                         ...      ...
#  5.0   $89K-$151K (Glassdoor est.)         1499       -1
#        $93K-$159K (Glassdoor est.)         1944       -1
#        $97K-$129K (Glassdoor est.)          852       -1
#        $98K-$114K (Glassdoor est.)          385       -1
#        $99K-$178K (Glassdoor est.)         1919       -1
#
# [1238 rows x 2 columns]

# %%
data.sort_values(by='Rating', ascending=False).head(100)
# Out:
#       Unnamed: 0                                          Job Title  \
# 1816        1816                                Junior Data Analyst
# 491          491              Senior Data Analyst- Secret Clearance
# 647          647                Operations Analyst, Data Governance
# 2181        2181                                       Data Analyst
# 551          551                                       Data Analyst
# ...          ...                                                ...
# 2220        2220  MDG Functional Data Analyst-Greenwood Village, CO
# 1218        1218                                       Data Analyst
# 446          446                                Senior Data Analyst
# 2221        2221                                Data Analyst Junior
# 1260        1260                                Junior Data Analyst
#
#                   Salary Estimate  \
# 1816   $50K-$86K (Glassdoor est.)
# 491   $49K-$112K (Glassdoor est.)
# 647    $42K-$66K (Glassdoor est.)
# ...

# %%
data[['Rating']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb8201df850>]],
#       dtype=object)

# %%
data.pivot_table('Rating', 'Salary Estimate', 'Location', 'max')
# Out:
# Location                      Addison, TX  Alachua, FL  Alameda, CA  \
# Salary Estimate
# $110K-$190K (Glassdoor est.)          NaN          NaN          NaN
# $113K-$132K (Glassdoor est.)          NaN          NaN          NaN
# $24K-$48K (Glassdoor est.)            NaN          NaN          NaN
# $26K-$47K (Glassdoor est.)            NaN          NaN          NaN
# $27K-$52K (Glassdoor est.)            NaN          NaN          NaN
# ...                                   ...          ...          ...
# $93K-$159K (Glassdoor est.)           NaN          NaN          NaN
# $97K-$129K (Glassdoor est.)           NaN          NaN          NaN
# $98K-$114K (Glassdoor est.)           NaN          NaN          NaN
# $99K-$178K (Glassdoor est.)           NaN          NaN          NaN
# -1                                    NaN          NaN          NaN
#
# Location                      Alhambra, CA  Allegheny West, PA  Allen, TX  \
# Salary Estimate
# ...

# %%
data[(data.Location == 'Whippany, NJ')&(data.Rating >= 4)].Sector
# Out:
# 380    Information Technology
# Name: Sector, dtype: object

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

import plotly.graph_objs as go

print(__version__) 

init_notebook_mode(connected=True)
# Out:
# 4.6.0
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
trace = go.Bar(
    y = data['Rating'][0:2000],
    x = data['Job Title'][0:2000],
    name = 'Rating')

data1 = [trace]

layout = go.Layout(title = 'Rating'
    , barmode = 'group'
    , xaxis=dict(title='Job Title')
    , yaxis=dict(title='Rating')
    , legend=dict(x=0.8,y=1.2)
    )

fig = go.Figure(data=data1, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="fa5b0d99-e874-4d85-877f-ab9059e6a4a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fa5b0d99-e874-4d85-877f-ab9059e6a4a2")) {
#                     Plotly.newPlot(
#                         'fa5b0d99-e874-4d85-877f-ab9059e6a4a2',
# ...
